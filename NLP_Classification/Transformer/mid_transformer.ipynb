# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.utils import to_categorical, plot_model
from tensorflow.keras.layers import *
from tensorflow.keras.models import Sequential, load_model, Model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint,  ReduceLROnPlateau
from tensorflow.keras.regularizers import *
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.optimizers import *
import tensorflow.keras.backend as K
from datetime import datetime
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
from google.colab import drive
drive.mount('/content/gdrive/')
import pickle
import gzip
# Out:
# Mounted at /content/gdrive/

# %%
with gzip.open('/content/gdrive/MyDrive/애쓰는 감자/data/mid_data/mid_y_val.pickle','rb') as f:
  mid_y_val = pickle.load(f)

# %%
len(mid_y_val)
# Out:
# 488386

# %%
class MultiHeadAttention(Layer):
    def __init__(self, embedding_dim, num_heads=8):
        super(MultiHeadAttention, self).__init__()
        self.embedding_dim = embedding_dim # d_model
        self.num_heads = num_heads

        assert embedding_dim % self.num_heads == 0

        self.projection_dim = embedding_dim // num_heads
        self.query_dense = Dense(embedding_dim)
        self.key_dense = Dense(embedding_dim)
        self.value_dense = Dense(embedding_dim)
        self.dense = Dense(embedding_dim)
    
    def get_config(self):
        config = super().get_config().copy()
        config.update({
            'embedding_dim' : self.embedding_dim,
            'num_heads' : self.num_heads,
            
            'projection_dim' : self.projection_dim,
            'query_dense' : self.query_dense,
            'key_dense' : self.key_dense,
            'value_dense' : self.value_dense,
            'dense' : self.dense
        })

    def scaled_dot_product_attention(self, query, key, value):
        matmul_qk = tf.matmul(query, key, transpose_b=True)
        depth = tf.cast(tf.shape(key)[-1], tf.float32)
        logits = matmul_qk / tf.math.sqrt(depth)
        attention_weights = tf.nn.softmax(logits, axis=-1)
        output = tf.matmul(attention_weights, value)
        return output, attention_weights

    def split_heads(self, x, batch_size):
        x = tf.reshape(x, (batch_size, -1, self.num_heads, self.projection_dim))
        return tf.transpose(x, perm=[0, 2, 1, 3])

    def call(self, inputs):
        # x.shape = [batch_size, seq_len, embedding_dim]
        batch_size = tf.shape(inputs)[0]

        # (batch_size, seq_len, embedding_dim)
        query = self.query_dense(inputs)
        key = self.key_dense(inputs)
        value = self.value_dense(inputs)

        # (batch_size, num_heads, seq_len, projection_dim)
        query = self.split_heads(query, batch_size)  
        key = self.split_heads(key, batch_size)
        value = self.split_heads(value, batch_size)

        scaled_attention, _ = self.scaled_dot_product_attention(query, key, value)
        # (batch_size, seq_len, num_heads, projection_dim)
        scaled_attention = tf.transpose(scaled_attention, perm=[0, 2, 1, 3])  

        # (batch_size, seq_len, embedding_dim)
        concat_attention = tf.reshape(scaled_attention, (batch_size, -1, self.embedding_dim))
        outputs = self.dense(concat_attention)
        return outputs

# %%
class TransformerBlock(Layer):
    def __init__(self, embedding_dim, num_heads, dff, rate=0.1):
        super(TransformerBlock, self).__init__()
        self.att = MultiHeadAttention(embedding_dim, num_heads)
        self.ffn = Sequential(
            [Dense(dff, activation="relu"),
             Dense(embedding_dim),]
        )
        self.layernorm1 = LayerNormalization(epsilon=1e-6)
        self.layernorm2 = LayerNormalization(epsilon=1e-6)
        self.dropout1 = Dropout(rate)
        self.dropout2 = Dropout(rate)
        
    def get_config(self):
        config = super().get_config().copy()
        config.update({
            'att' : self.att,
            'ffn' : self.ffn,
            'layernorm1' : self.layernorm1,
            'layernorm2' : self.layernorm2,
            'dropout1' : self.dropout1,
            'dropout2' : self.dropout2
        })

    def call(self, inputs, training):
        attn_output = self.att(inputs)
        attn_output = self.dropout1(attn_output, training=training)
        out1 = self.layernorm1(inputs + attn_output)
        ffn_output = self.ffn(out1)
        ffn_output = self.dropout2(ffn_output, training=training)
        return self.layernorm2(out1 + ffn_output)

# %%
class TokenAndPositionEmbedding(Layer):
    def __init__(self, max_len, vocab_size, embedding_dim):
        super(TokenAndPositionEmbedding, self).__init__()
        self.token_emb = Embedding(vocab_size, embedding_dim)
        self.pos_emb = Embedding(max_len, embedding_dim)
        
    def get_config(self):
        config = super().get_config().copy()
        config.update({
            'token_emb' : self.token_emb,
            'pos_emb' : self.pos_emb,
        })
        return config

    def call(self, x):
        max_len = tf.shape(x)[-1]
        positions = tf.range(start=0, limit=max_len, delta=1)
        positions = self.pos_emb(positions)
        x = self.token_emb(x)
        return x + positions

# %%
with gzip.open('/content/gdrive/MyDrive/애쓰는 감자/data/mid_data/pad_X_train.pickle','rb') as f:
  pad_X_train = pickle.load(f)
with gzip.open('/content/gdrive/MyDrive/애쓰는 감자/data/mid_data/mid_train_y.pickle','rb') as f:
  mid_train_y = pickle.load(f)
with gzip.open('/content/gdrive/MyDrive/애쓰는 감자/data/mid_data/mid_y_val.pickle','rb') as f:
  mid_y_val = pickle.load(f)
with gzip.open('/content/gdrive/MyDrive/애쓰는 감자/data/preprocessing_data/pad_X_val.pickle','rb') as f:
  pad_X_val = pickle.load(f)

# %%
len(mid_y_val[0])
# Out:
# 77

# %%
max_len = 300
embedding_dim = 32  # Embedding size for each token
num_heads = 4  # Number of attention heads
dff = 32  # Hidden layer size in feed forward network inside transformer
vocab_size = 18658 # Transformer1에 있음
inputs = Input(shape=(max_len,))
embedding_layer = TokenAndPositionEmbedding(max_len, vocab_size, embedding_dim)
x = embedding_layer(inputs)
transformer_block = TransformerBlock(embedding_dim, num_heads, dff)
x = transformer_block(x)
x = GlobalAveragePooling1D()(x)
x = Dropout(0.5)(x)
x = Dense(100, activation="relu")(x)
x = Dropout(0.5)(x)
outputs = Dense(77, activation="softmax")(x)
model = Model(inputs=inputs, outputs=outputs)

# %%
import os
path = '/content/gdrive/MyDrive/애쓰는 감자/코드/kym/mid_weights/'
ckpt_1 = 'Transformer.ckpt'
model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])
mc = ModelCheckpoint(filepath =  os.path.join(path, ckpt_1), monitor = 'val_accuracy', save_best_only = True, mode = 'max',verbose = 1, save_weights_only=True)
es = EarlyStopping(monitor='loss', mode='min', verbose=1, patience = 5)

# %%
history = model.fit(pad_X_train, mid_train_y, batch_size=128, epochs=100, validation_split=0.2, callbacks = [mc,es])
# Out:
# Epoch 1/100
# 7123/7123 [==============================] - 300s 42ms/step - loss: 1.8667 - accuracy: 0.5165 - val_loss: 1.3255 - val_accuracy: 0.6482
#
# Epoch 00001: val_accuracy improved from -inf to 0.64820, saving model to /content/gdrive/MyDrive/애쓰는 감자/코드/kym/mid_weights/Transformer.ckpt
# Epoch 2/100
# 7123/7123 [==============================] - 299s 42ms/step - loss: 1.5493 - accuracy: 0.6008 - val_loss: 1.2290 - val_accuracy: 0.6749
#
# Epoch 00002: val_accuracy improved from 0.64820 to 0.67485, saving model to /content/gdrive/MyDrive/애쓰는 감자/코드/kym/mid_weights/Transformer.ckpt
# Epoch 3/100
# 7123/7123 [==============================] - 299s 42ms/step - loss: 1.4653 - accuracy: 0.6253 - val_loss: 1.1882 - val_accuracy: 0.6876
#
# Epoch 00003: val_accuracy improved from 0.67485 to 0.68763, saving model to /content/gdrive/MyDrive/애쓰는 감자/코드/kym/mid_weights/Transformer.ckpt
# Epoch 4/100
# 7123/7123 [==============================] - 297s 42ms/step - loss: 1.4152 - accuracy: 0.6389 - val_loss: 1.1752 - val_accuracy: 0.6901
#
# Epoch 00004: val_accuracy improved from 0.68763 to 0.69011, saving model to /content/gdrive/MyDrive/애쓰는 감자/코드/kym/mid_weights/Transformer.ckpt
# Epoch 5/100
# 7123/7123 [==============================] - 298s 42ms/step - loss: 1.3829 - accuracy: 0.6484 - val_loss: 1.1590 - val_accuracy: 0.6955
#
# Epoch 00005: val_accuracy improved from 0.69011 to 0.69545, saving model to /content/gdrive/MyDrive/애쓰는 감자/코드/kym/mid_weights/Transformer.ckpt
# Epoch 6/100
# 7123/7123 [==============================] - 298s 42ms/step - loss: 1.3574 - accuracy: 0.6548 - val_loss: 1.1522 - val_accuracy: 0.6974
#
# Epoch 00006: val_accuracy improved from 0.69545 to 0.69740, saving model to /content/gdrive/MyDrive/애쓰는 감자/코드/kym/mid_weights/Transformer.ckpt
# Epoch 7/100
# 7123/7123 [==============================] - 297s 42ms/step - loss: 1.3372 - accuracy: 0.6606 - val_loss: 1.1471 - val_accuracy: 0.6994
#
# Epoch 00007: val_accuracy improved from 0.69740 to 0.69941, saving model to /content/gdrive/MyDrive/애쓰는 감자/코드/kym/mid_weights/Transformer.ckpt
# Epoch 8/100
# 7123/7123 [==============================] - 299s 42ms/step - loss: 1.3209 - accuracy: 0.6645 - val_loss: 1.1422 - val_accuracy: 0.7022
#
# Epoch 00008: val_accuracy improved from 0.69941 to 0.70216, saving model to /content/gdrive/MyDrive/애쓰는 감자/코드/kym/mid_weights/Transformer.ckpt
# Epoch 9/100
# 7123/7123 [==============================] - 299s 42ms/step - loss: 1.3065 - accuracy: 0.6687 - val_loss: 1.1469 - val_accuracy: 0.7011
#
# Epoch 00009: val_accuracy did not improve from 0.70216
# Epoch 10/100
# 7123/7123 [==============================] - 300s 42ms/step - loss: 1.2921 - accuracy: 0.6724 - val_loss: 1.1434 - val_accuracy: 0.7042
#
# Epoch 00010: val_accuracy improved from 0.70216 to 0.70422, saving model to /content/gdrive/MyDrive/애쓰는 감자/코드/kym/mid_weights/Transformer.ckpt
# Epoch 11/100
# 7123/7123 [==============================] - 298s 42ms/step - loss: 1.2819 - accuracy: 0.6749 - val_loss: 1.1392 - val_accuracy: 0.7048
#
# Epoch 00011: val_accuracy improved from 0.70422 to 0.70477, saving model to /content/gdrive/MyDrive/애쓰는 감자/코드/kym/mid_weights/Transformer.ckpt
# Epoch 12/100
# 7123/7123 [==============================] - 300s 42ms/step - loss: 1.2714 - accuracy: 0.6773 - val_loss: 1.1379 - val_accuracy: 0.7044
#
# Epoch 00012: val_accuracy did not improve from 0.70477
# Epoch 13/100
# 7123/7123 [==============================] - 298s 42ms/step - loss: 1.2627 - accuracy: 0.6799 - val_loss: 1.1376 - val_accuracy: 0.7064
#
# Epoch 00013: val_accuracy improved from 0.70477 to 0.70642, saving model to /content/gdrive/MyDrive/애쓰는 감자/코드/kym/mid_weights/Transformer.ckpt
# Epoch 14/100
# 7123/7123 [==============================] - 297s 42ms/step - loss: 1.2549 - accuracy: 0.6817 - val_loss: 1.1429 - val_accuracy: 0.7050
#
# Epoch 00014: val_accuracy did not improve from 0.70642
# Epoch 15/100
# 7123/7123 [==============================] - 297s 42ms/step - loss: 1.2464 - accuracy: 0.6836 - val_loss: 1.1508 - val_accuracy: 0.7054
#
# Epoch 00015: val_accuracy did not improve from 0.70642
# Epoch 16/100
# 7123/7123 [==============================] - 297s 42ms/step - loss: 1.2401 - accuracy: 0.6853 - val_loss: 1.1456 - val_accuracy: 0.7066
#
# Epoch 00016: val_accuracy improved from 0.70642 to 0.70657, saving model to /content/gdrive/MyDrive/애쓰는 감자/코드/kym/mid_weights/Transformer.ckpt
# Epoch 17/100
# 7123/7123 [==============================] - 297s 42ms/step - loss: 1.2334 - accuracy: 0.6867 - val_loss: 1.1475 - val_accuracy: 0.7063
#
# Epoch 00017: val_accuracy did not improve from 0.70657
# Epoch 18/100
# 7123/7123 [==============================] - 296s 42ms/step - loss: 1.2276 - accuracy: 0.6881 - val_loss: 1.1631 - val_accuracy: 0.7083
#
# Epoch 00018: val_accuracy improved from 0.70657 to 0.70831, saving model to /content/gdrive/MyDrive/애쓰는 감자/코드/kym/mid_weights/Transformer.ckpt
# Epoch 19/100
# 7123/7123 [==============================] - 295s 41ms/step - loss: 1.2204 - accuracy: 0.6895 - val_loss: 1.1533 - val_accuracy: 0.7076
#
# Epoch 00019: val_accuracy did not improve from 0.70831
# Epoch 20/100
# 7123/7123 [==============================] - 295s 41ms/step - loss: 1.2157 - accuracy: 0.6908 - val_loss: 1.1575 - val_accuracy: 0.7072
#
# Epoch 00020: val_accuracy did not improve from 0.70831
# Epoch 21/100
# 7123/7123 [==============================] - 295s 41ms/step - loss: 1.2105 - accuracy: 0.6922 - val_loss: 1.1595 - val_accuracy: 0.7076
#
# Epoch 00021: val_accuracy did not improve from 0.70831
# Epoch 22/100
# 7123/7123 [==============================] - 294s 41ms/step - loss: 1.2047 - accuracy: 0.6937 - val_loss: 1.1682 - val_accuracy: 0.7063
#
# Epoch 00022: val_accuracy did not improve from 0.70831
# Epoch 23/100
# 7123/7123 [==============================] - 294s 41ms/step - loss: 1.2020 - accuracy: 0.6945 - val_loss: 1.1628 - val_accuracy: 0.7070
#
# Epoch 00023: val_accuracy did not improve from 0.70831
# Epoch 24/100
# 7123/7123 [==============================] - 294s 41ms/step - loss: 1.1964 - accuracy: 0.6961 - val_loss: 1.1703 - val_accuracy: 0.7073
#
# Epoch 00024: val_accuracy did not improve from 0.70831
# Epoch 25/100
# 7123/7123 [==============================] - 301s 42ms/step - loss: 1.1914 - accuracy: 0.6971 - val_loss: 1.1755 - val_accuracy: 0.7080
#
# Epoch 00025: val_accuracy did not improve from 0.70831
# Epoch 26/100
# 7123/7123 [==============================] - 298s 42ms/step - loss: 1.1872 - accuracy: 0.6977 - val_loss: 1.1754 - val_accuracy: 0.7091
#
# Epoch 00026: val_accuracy improved from 0.70831 to 0.70909, saving model to /content/gdrive/MyDrive/애쓰는 감자/코드/kym/mid_weights/Transformer.ckpt
# Epoch 27/100
# 7123/7123 [==============================] - 302s 42ms/step - loss: 1.1840 - accuracy: 0.6987 - val_loss: 1.1867 - val_accuracy: 0.7065
#
# Epoch 00027: val_accuracy did not improve from 0.70909
# Epoch 28/100
# 7123/7123 [==============================] - 307s 43ms/step - loss: 1.1807 - accuracy: 0.6994 - val_loss: 1.1854 - val_accuracy: 0.7064
#
# Epoch 00028: val_accuracy did not improve from 0.70909
# Epoch 29/100
# 7123/7123 [==============================] - 302s 42ms/step - loss: 1.1765 - accuracy: 0.7006 - val_loss: 1.1846 - val_accuracy: 0.7069
#
# Epoch 00029: val_accuracy did not improve from 0.70909
# Epoch 30/100
# 7123/7123 [==============================] - 300s 42ms/step - loss: 1.1737 - accuracy: 0.7012 - val_loss: 1.1877 - val_accuracy: 0.7065
#
# Epoch 00030: val_accuracy did not improve from 0.70909
# Epoch 31/100
# 7123/7123 [==============================] - 300s 42ms/step - loss: 1.1693 - accuracy: 0.7020 - val_loss: 1.1890 - val_accuracy: 0.7065
#
# Epoch 00031: val_accuracy did not improve from 0.70909
# Epoch 32/100
# 7123/7123 [==============================] - 298s 42ms/step - loss: 1.1659 - accuracy: 0.7034 - val_loss: 1.2004 - val_accuracy: 0.7060
#
# Epoch 00032: val_accuracy did not improve from 0.70909
# Epoch 33/100
# 7123/7123 [==============================] - 298s 42ms/step - loss: 1.1620 - accuracy: 0.7044 - val_loss: 1.2054 - val_accuracy: 0.7056
#
# Epoch 00033: val_accuracy did not improve from 0.70909
# Epoch 34/100
# 7123/7123 [==============================] - 297s 42ms/step - loss: 1.1577 - accuracy: 0.7052 - val_loss: 1.2058 - val_accuracy: 0.7048
#
# Epoch 00034: val_accuracy did not improve from 0.70909
# Epoch 35/100
# 7123/7123 [==============================] - 297s 42ms/step - loss: 1.1560 - accuracy: 0.7060 - val_loss: 1.2043 - val_accuracy: 0.7065
#
# Epoch 00035: val_accuracy did not improve from 0.70909
# Epoch 36/100
# 7123/7123 [==============================] - 298s 42ms/step - loss: 1.1534 - accuracy: 0.7063 - val_loss: 1.2066 - val_accuracy: 0.7056
#
# Epoch 00036: val_accuracy did not improve from 0.70909
# Epoch 37/100
# 7123/7123 [==============================] - 297s 42ms/step - loss: 1.1512 - accuracy: 0.7070 - val_loss: 1.2135 - val_accuracy: 0.7053
#
# Epoch 00037: val_accuracy did not improve from 0.70909
# Epoch 38/100
# 7123/7123 [==============================] - 300s 42ms/step - loss: 1.1466 - accuracy: 0.7077 - val_loss: 1.2347 - val_accuracy: 0.7056
#
# Epoch 00038: val_accuracy did not improve from 0.70909
# Epoch 39/100
# 7123/7123 [==============================] - 301s 42ms/step - loss: 1.1439 - accuracy: 0.7083 - val_loss: 1.2164 - val_accuracy: 0.7045
#
# Epoch 00039: val_accuracy did not improve from 0.70909
# Epoch 40/100
# 7123/7123 [==============================] - 299s 42ms/step - loss: 1.1413 - accuracy: 0.7093 - val_loss: 1.2236 - val_accuracy: 0.7055
#
# Epoch 00040: val_accuracy did not improve from 0.70909
# Epoch 41/100
# 7123/7123 [==============================] - 298s 42ms/step - loss: 1.1389 - accuracy: 0.7100 - val_loss: 1.2324 - val_accuracy: 0.7041
#
# Epoch 00041: val_accuracy did not improve from 0.70909
# Epoch 42/100
# 7123/7123 [==============================] - 300s 42ms/step - loss: 1.1359 - accuracy: 0.7103 - val_loss: 1.2247 - val_accuracy: 0.7048
#
# Epoch 00042: val_accuracy did not improve from 0.70909
# Epoch 43/100
# 5249/7123 [=====================>........] - ETA: 1:12 - loss: 1.1308 - accuracy: 0.7122

# %%
path = '/content/gdrive/MyDrive/애쓰는 감자/코드/kym/mid_weights/'
ckpt_1 = 'Transformer.ckpt'
model.load_weights(path+ckpt_1)

# %%
len(mid_y_val)
# Out:
# 488386

# %%
score_board = []
pred_val = model.predict(pad_X_val)
for true,pred in zip(mid_y_val,pred_val):
  if np.argmax(true) == np.argmax(pred):
    score_board.append(1)
  else:
    score_board.append(0)
print('Accuracy',np.array(score_board).sum()/len(score_board)*100)
# Out:
# Accuracy 70.7620611565442

# %%
data = pd.read_csv('/content/gdrive/MyDrive/애쓰는 감자/data/Pre3.csv')

# %%
data['mid'] = data['KSIC10_BZC_CD'].apply(lambda x: x[1:3])

# %%
ls = data['mid'].unique().tolist()

# %%
final_ls = []
for i in ls:
  if len(i)==2:
    final_ls.append(i)
final_ls = sorted(final_ls)

# %%
predict_val_name = []
for i in pred_val:
  idx = np.argmax(i)
  predict_val_name.append(final_ls[idx])
Transformer_val = pd.read_csv('/content/gdrive/MyDrive/애쓰는 감자/코드/kym/output/Transformer_predict_val.csv')
Transformer_val['mid'] = predict_val_name

# %%
# Transformer_val.to_csv('/content/gdrive/MyDrive/애쓰는 감자/코드/kym/output/Transformer_predict_val.csv',index=False)

# %%
with gzip.open('/content/gdrive/MyDrive/애쓰는 감자/data/preprocessing_data/pad_X_test.pickle','rb') as f:
  pad_X_test = pickle.load(f)
pred_test = model.predict(pad_X_test)

# %%
predict_test_name = []
for i in pred_test:
  idx = np.argmax(i)
  predict_test_name.append(final_ls[idx])
Transformer_test = pd.read_csv('/content/gdrive/MyDrive/애쓰는 감자/코드/kym/output/Transformer_predict_test.csv')
Transformer_test['mid'] = predict_test_name

# %%
Transformer_test.to_csv('/content/gdrive/MyDrive/애쓰는 감자/코드/kym/output/Transformer_predict_test.csv',index=False)

# %%
predict_train = model.predict(pad_X_train)
with gzip.open('/content/gdrive/MyDrive/애쓰는 감자/코드/kym/output/Transformer_predict_train_mid.pickle','wb') as f:
  pickle.dump(predict_train,f)
