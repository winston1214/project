# %% [markdown]
# <font color=yellow>train data - 중분류</font>

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
train = pd.read_csv('/content/drive/MyDrive/애쓰는 감자/data/train.csv')
train.head()
# Out:
#        KEDCD                                    BZ_PPOS_ITM_CTT  ...  mid Big
# 0  7695516.0   농산물 판매업  전자상거래업  통신판매업농임산물 건강기능식품 건강보조식품 일반식품...  ...  G46   G
# 1  8177802.0   건축공사업  토목공사업  토공사업  토목건축공사업  철근콘크리트공사업  실내인테리...  ...  F41   F
# 2  8233352.0   음식점업 경양식 퓨전 한식 중식 일식  식품 제조 가공 유통 판매 도소매업  제과...  ...  I56   I
# 3   991833.0   변호사의 직무에 속하는 업무  공증인의 직무에 속하는 업무  변호사법 제조에 속하...  ...  M71   M
# 4  7305137.0          일반폐기물처리업  재활용사업  정화조 청소업  위 각항에 부대되는 사업일체  ...  E38   E
#
# [5 rows x 5 columns]

# %%
val = pd.read_csv('/content/drive/MyDrive/애쓰는 감자/data/val.csv')
val.head()
# Out:
#        KEDCD                                    BZ_PPOS_ITM_CTT  ...  mid Big
# 0  8324863.0   생활용품 및 잡화 도소매업  건강식품 건강보조식품 도소매업  유통업  의료용품 기...  ...  G46   G
# 1  5179736.0   판넬 제조및 공사업  판넬 도소매업  창호 철물 공사업  실내외 인테리어 공사업 ...  ...  F42   F
# 2  7201804.0   인테리어 및 건축 디자인업  인테리어 및 건축 시공업  인테리어 소품 도소매업  ...  ...  M73   M
# 3  5180592.0   형질전환잔디 품종개발생산재배판매  생명공학에 의한 일반작물 식물의 품종개발생산재배...  ...  G47   G
# 4  8042873.0   태양광 전력 발전사업  태양광 전력 판매사업  시설물 유지 관리업  전기공사업  ...  ...  D35   D
#
# [5 rows x 5 columns]

# %%
len(train)
# Out:
# 1139568

# %%
len(val)
# Out:
# 488386

# %%
for i in range(len(train)):
  if len(train['KSIC10_BZC_CD'][i])<3:
    train=train.drop(index=i)

print(len(train))
# Out:
# 1139566

# %%
for i in range(len(val)):
  if len(val['KSIC10_BZC_CD'][i])<3:
    val=val.drop(index=i)

print(len(val))
# Out:
# 488386

# %%
train['mid']=train['KSIC10_BZC_CD'].str[1:3]
train.head()
# Out:
#        KEDCD                                    BZ_PPOS_ITM_CTT  ... mid Big
# 0  7695516.0   농산물 판매업  전자상거래업  통신판매업농임산물 건강기능식품 건강보조식품 일반식품...  ...  46   G
# 1  8177802.0   건축공사업  토목공사업  토공사업  토목건축공사업  철근콘크리트공사업  실내인테리...  ...  41   F
# 2  8233352.0   음식점업 경양식 퓨전 한식 중식 일식  식품 제조 가공 유통 판매 도소매업  제과...  ...  56   I
# 3   991833.0   변호사의 직무에 속하는 업무  공증인의 직무에 속하는 업무  변호사법 제조에 속하...  ...  71   M
# 4  7305137.0          일반폐기물처리업  재활용사업  정화조 청소업  위 각항에 부대되는 사업일체  ...  38   E
#
# [5 rows x 5 columns]

# %%
for i in range(len(train)):
  if len(train['KSIC10_BZC_CD'][i])<4:
    train=train.drop(index=i)

print(len(train))
# Out:
# 1121856

# %%
train['small']=train['KSIC10_BZC_CD'].str[1:4]
train.head()
# Out:
#        KEDCD                                    BZ_PPOS_ITM_CTT  ... Big small_
# 0  7695516.0   농산물 판매업  전자상거래업  통신판매업농임산물 건강기능식품 건강보조식품 일반식품...  ...   G    462
# 1  8177802.0   건축공사업  토목공사업  토공사업  토목건축공사업  철근콘크리트공사업  실내인테리...  ...   F    412
# 2  8233352.0   음식점업 경양식 퓨전 한식 중식 일식  식품 제조 가공 유통 판매 도소매업  제과...  ...   I    561
# 3   991833.0   변호사의 직무에 속하는 업무  공증인의 직무에 속하는 업무  변호사법 제조에 속하...  ...   M    711
# 4  7305137.0          일반폐기물처리업  재활용사업  정화조 청소업  위 각항에 부대되는 사업일체  ...   E    382
#
# [5 rows x 6 columns]

# %%
# 라벨링

from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
encoder.fit(train['small'])
train['small_idx'] = encoder.transform(train['small'])
train.head()
# Out:
#        KEDCD  ... small__idx
# 0  7695516.0  ...        162
# 1  8177802.0  ...        148
# 2  8233352.0  ...        198
# 3   991833.0  ...        234
# 4  7305137.0  ...        142
#
# [5 rows x 7 columns]

# %%
# 라벨링된 것 매핑

mapping = dict(zip(range(len(encoder.classes_)), encoder.classes_))
mapping
# Out:
# {0: '',
#  1: '01',
#  2: '011',
#  3: '012',
#  4: '013',
#  5: '014',
#  6: '015',
#  7: '02',
#  8: '020',
#  9: '03',
#  10: '031',
#  11: '032',
#  12: '05',
#  13: '051',
#  14: '052',
#  15: '06',
#  16: '061',
#  17: '062',
#  18: '07',
#  19: '071',
#  20: '072',
#  21: '08',
#  22: '080',
#  23: '10',
#  24: '101',
#  25: '102',
#  26: '103',
#  27: '104',
#  28: '105',
#  29: '106',
#  30: '107',
#  31: '108',
#  32: '11',
#  33: '111',
#  34: '112',
#  35: '12',
#  36: '120',
#  37: '13',
#  38: '131',
#  39: '132',
#  40: '133',
#  41: '134',
#  42: '139',
#  43: '14',
#  44: '141',
#  45: '142',
#  46: '143',
#  47: '144',
#  48: '15',
#  49: '151',
#  50: '152',
#  51: '16',
#  52: '161',
#  53: '162',
#  54: '163',
#  55: '17',
#  56: '171',
#  57: '172',
#  58: '179',
#  59: '18',
#  60: '181',
#  61: '182',
#  62: '19',
#  63: '191',
#  64: '192',
#  65: '20',
#  66: '201',
#  67: '202',
#  68: '203',
#  69: '204',
#  70: '205',
#  71: '21',
#  72: '211',
# ...

# %%
train['small'].unique()

# %%
val['mid']=val['KSIC10_BZC_CD'].str[1:3]
val.head()
# Out:
#        KEDCD                                    BZ_PPOS_ITM_CTT  ... mid Big
# 0  8324863.0   생활용품 및 잡화 도소매업  건강식품 건강보조식품 도소매업  유통업  의료용품 기...  ...  46   G
# 1  5179736.0   판넬 제조및 공사업  판넬 도소매업  창호 철물 공사업  실내외 인테리어 공사업 ...  ...  42   F
# 2  7201804.0   인테리어 및 건축 디자인업  인테리어 및 건축 시공업  인테리어 소품 도소매업  ...  ...  73   M
# 3  5180592.0   형질전환잔디 품종개발생산재배판매  생명공학에 의한 일반작물 식물의 품종개발생산재배...  ...  47   G
# 4  8042873.0   태양광 전력 발전사업  태양광 전력 판매사업  시설물 유지 관리업  전기공사업  ...  ...  35   D
#
# [5 rows x 5 columns]

# %%
# 라벨링

from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
encoder.fit(train['mid'])
train['mid_idx'] = encoder.transform(train['mid'])
train.head()
# Out:
#        KEDCD                                    BZ_PPOS_ITM_CTT  ... Big mid_idx
# 0  7695516.0   농산물 판매업  전자상거래업  통신판매업농임산물 건강기능식품 건강보조식품 일반식품...  ...   G      40
# 1  8177802.0   건축공사업  토목공사업  토공사업  토목건축공사업  철근콘크리트공사업  실내인테리...  ...   F      37
# 2  8233352.0   음식점업 경양식 퓨전 한식 중식 일식  식품 제조 가공 유통 판매 도소매업  제과...  ...   I      47
# 3   991833.0   변호사의 직무에 속하는 업무  공증인의 직무에 속하는 업무  변호사법 제조에 속하...  ...   M      59
# 4  7305137.0          일반폐기물처리업  재활용사업  정화조 청소업  위 각항에 부대되는 사업일체  ...   E      35
#
# [5 rows x 6 columns]

# %%
# 라벨링된 것 매핑

mapping = dict(zip(range(len(encoder.classes_)), encoder.classes_))
mapping
# Out:
# {0: '01',
#  1: '02',
#  2: '03',
#  3: '05',
#  4: '06',
#  5: '07',
#  6: '08',
#  7: '10',
#  8: '11',
#  9: '12',
#  10: '13',
#  11: '14',
#  12: '15',
#  13: '16',
#  14: '17',
#  15: '18',
#  16: '19',
#  17: '20',
#  18: '21',
#  19: '22',
#  20: '23',
#  21: '24',
#  22: '25',
#  23: '26',
#  24: '27',
#  25: '28',
#  26: '29',
#  27: '30',
#  28: '31',
#  29: '32',
#  30: '33',
#  31: '34',
#  32: '35',
#  33: '36',
#  34: '37',
#  35: '38',
#  36: '39',
#  37: '41',
#  38: '42',
#  39: '45',
#  40: '46',
#  41: '47',
#  42: '49',
#  43: '50',
#  44: '51',
#  45: '52',
#  46: '55',
#  47: '56',
#  48: '58',
#  49: '59',
#  50: '60',
#  51: '61',
#  52: '62',
#  53: '63',
#  54: '64',
#  55: '65',
#  56: '66',
#  57: '68',
#  58: '70',
#  59: '71',
#  60: '72',
#  61: '73',
#  62: '74',
#  63: '75',
#  64: '76',
#  65: '84',
#  66: '85',
#  67: '86',
#  68: '87',
#  69: '90',
#  70: '91',
#  71: '94',
#  72: '95',
#  73: '96',
#  74: '97',
#  75: '98',
#  76: '99'}

# %%
train = train.loc[:,['BZ_PPOS_ITM_CTT', 'mid_idx']]
train.head()
# Out:
#                                      BZ_PPOS_ITM_CTT  mid_idx
# 0   농산물 판매업  전자상거래업  통신판매업농임산물 건강기능식품 건강보조식품 일반식품...       40
# 1   건축공사업  토목공사업  토공사업  토목건축공사업  철근콘크리트공사업  실내인테리...       37
# 2   음식점업 경양식 퓨전 한식 중식 일식  식품 제조 가공 유통 판매 도소매업  제과...       47
# 3   변호사의 직무에 속하는 업무  공증인의 직무에 속하는 업무  변호사법 제조에 속하...       59
# 4          일반폐기물처리업  재활용사업  정화조 청소업  위 각항에 부대되는 사업일체       35

# %%
len(train)
# Out:
# 1139566

# %%
i = len(train) // 2
print(i)
# Out:
# 569783

# %%
train = train.reset_index(drop=True)
train.head()
# Out:
#                                      BZ_PPOS_ITM_CTT  mid_idx
# 0   농산물 판매업  전자상거래업  통신판매업농임산물 건강기능식품 건강보조식품 일반식품...       40
# 1   건축공사업  토목공사업  토공사업  토목건축공사업  철근콘크리트공사업  실내인테리...       37
# 2   음식점업 경양식 퓨전 한식 중식 일식  식품 제조 가공 유통 판매 도소매업  제과...       47
# 3   변호사의 직무에 속하는 업무  공증인의 직무에 속하는 업무  변호사법 제조에 속하...       59
# 4          일반폐기물처리업  재활용사업  정화조 청소업  위 각항에 부대되는 사업일체       35

# %%
train_mid_1 = train[:i]
train_mid_1.head()
# Out:
#                                      BZ_PPOS_ITM_CTT  mid_idx
# 0   농산물 판매업  전자상거래업  통신판매업농임산물 건강기능식품 건강보조식품 일반식품...       40
# 1   건축공사업  토목공사업  토공사업  토목건축공사업  철근콘크리트공사업  실내인테리...       37
# 2   음식점업 경양식 퓨전 한식 중식 일식  식품 제조 가공 유통 판매 도소매업  제과...       47
# 3   변호사의 직무에 속하는 업무  공증인의 직무에 속하는 업무  변호사법 제조에 속하...       59
# 4          일반폐기물처리업  재활용사업  정화조 청소업  위 각항에 부대되는 사업일체       35

# %%
train_mid_2 = train[i:]
train_mid_2.head()
# Out:
#                                           BZ_PPOS_ITM_CTT  mid_idx
# 569783   자동차부품 제조업  산업플랜트 건설업  조선기자재 제조업  무역 및 도매업  엔지...       27
# 569784  계는 협동적 자치정신을 현현하여 임업의 건전한 발전을 기함을 목적으로 한다  공동사...        1
# 569785   부동산중개업  상업용 건축물 및 주택의 임대관리 등 부동산의 관리대행  부동산 이...       57
# 569786   아파트 체육시설관리업  스포츠센터 및 휘트니스센터운영  스포츠관련 사업컨설팅  스...       70
# 569787   재생 플라스틱 칩 원료 생산업  재생 플라스틱 제조업  재생 플라스틱 도소매업  ...       17

# %%
len(train_mid_1)
# Out:
# 569783

# %%
len(train_mid_2)
# Out:
# 569783

# %%
train_mid_1.to_csv('train_mid_1.txt', sep='\t', index=True)

# %%
train_mid_2.to_csv('train_mid_2.txt', sep='\t', index=True)

# %%
# 라벨링

from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
encoder.fit(val['mid'])
val['mid_idx'] = encoder.transform(val['mid'])
val.head()
# Out:
#        KEDCD                                    BZ_PPOS_ITM_CTT  ... Big mid_idx
# 0  8324863.0   생활용품 및 잡화 도소매업  건강식품 건강보조식품 도소매업  유통업  의료용품 기...  ...   G      40
# 1  5179736.0   판넬 제조및 공사업  판넬 도소매업  창호 철물 공사업  실내외 인테리어 공사업 ...  ...   F      38
# 2  7201804.0   인테리어 및 건축 디자인업  인테리어 및 건축 시공업  인테리어 소품 도소매업  ...  ...   M      61
# 3  5180592.0   형질전환잔디 품종개발생산재배판매  생명공학에 의한 일반작물 식물의 품종개발생산재배...  ...   G      41
# 4  8042873.0   태양광 전력 발전사업  태양광 전력 판매사업  시설물 유지 관리업  전기공사업  ...  ...   D      32
#
# [5 rows x 6 columns]

# %%
# 라벨링된 것 매핑

mapping = dict(zip(range(len(encoder.classes_)), encoder.classes_))
mapping
# Out:
# {0: '01',
#  1: '02',
#  2: '03',
#  3: '05',
#  4: '06',
#  5: '07',
#  6: '08',
#  7: '10',
#  8: '11',
#  9: '12',
#  10: '13',
#  11: '14',
#  12: '15',
#  13: '16',
#  14: '17',
#  15: '18',
#  16: '19',
#  17: '20',
#  18: '21',
#  19: '22',
#  20: '23',
#  21: '24',
#  22: '25',
#  23: '26',
#  24: '27',
#  25: '28',
#  26: '29',
#  27: '30',
#  28: '31',
#  29: '32',
#  30: '33',
#  31: '34',
#  32: '35',
#  33: '36',
#  34: '37',
#  35: '38',
#  36: '39',
#  37: '41',
#  38: '42',
#  39: '45',
#  40: '46',
#  41: '47',
#  42: '49',
#  43: '50',
#  44: '51',
#  45: '52',
#  46: '55',
#  47: '56',
#  48: '58',
#  49: '59',
#  50: '60',
#  51: '61',
#  52: '62',
#  53: '63',
#  54: '64',
#  55: '65',
#  56: '66',
#  57: '68',
#  58: '70',
#  59: '71',
#  60: '72',
#  61: '73',
#  62: '74',
#  63: '75',
#  64: '76',
#  65: '84',
#  66: '85',
#  67: '86',
#  68: '87',
#  69: '90',
#  70: '91',
#  71: '94',
#  72: '95',
#  73: '96',
#  74: '97',
#  75: '98',
#  76: '99'}

# %%
val= val.loc[:,['BZ_PPOS_ITM_CTT', 'mid_idx']]
val.head()
# Out:
#                                      BZ_PPOS_ITM_CTT  mid_idx
# 0   생활용품 및 잡화 도소매업  건강식품 건강보조식품 도소매업  유통업  의료용품 기...       40
# 1   판넬 제조및 공사업  판넬 도소매업  창호 철물 공사업  실내외 인테리어 공사업 ...       38
# 2   인테리어 및 건축 디자인업  인테리어 및 건축 시공업  인테리어 소품 도소매업  ...       61
# 3   형질전환잔디 품종개발생산재배판매  생명공학에 의한 일반작물 식물의 품종개발생산재배...       41
# 4   태양광 전력 발전사업  태양광 전력 판매사업  시설물 유지 관리업  전기공사업  ...       32

# %%
len(val)
# Out:
# 488386

# %%
val.to_csv('val_mid.txt', sep='\t', index=True)

# %% [markdown]
# <font color=yellow> val - small </font>

# %%
val = pd.read_csv('/content/drive/MyDrive/애쓰는 감자/data/val.csv')
val.head()
# Out:
#        KEDCD                                    BZ_PPOS_ITM_CTT  ...  mid Big
# 0  8324863.0   생활용품 및 잡화 도소매업  건강식품 건강보조식품 도소매업  유통업  의료용품 기...  ...  G46   G
# 1  5179736.0   판넬 제조및 공사업  판넬 도소매업  창호 철물 공사업  실내외 인테리어 공사업 ...  ...  F42   F
# 2  7201804.0   인테리어 및 건축 디자인업  인테리어 및 건축 시공업  인테리어 소품 도소매업  ...  ...  M73   M
# 3  5180592.0   형질전환잔디 품종개발생산재배판매  생명공학에 의한 일반작물 식물의 품종개발생산재배...  ...  G47   G
# 4  8042873.0   태양광 전력 발전사업  태양광 전력 판매사업  시설물 유지 관리업  전기공사업  ...  ...  D35   D
#
# [5 rows x 5 columns]

# %%
len(val)
# Out:
# 488386

# %%
for i in range(len(val)):
  if len(val['KSIC10_BZC_CD'][i])<4:
    val=val.drop(index=i)

print(len(val))
# Out:
# 480709

# %%
val['small']=val['KSIC10_BZC_CD'].str[1:4]
val.head()
# Out:
#        KEDCD                                    BZ_PPOS_ITM_CTT  ... Big small
# 0  8324863.0   생활용품 및 잡화 도소매업  건강식품 건강보조식품 도소매업  유통업  의료용품 기...  ...   G   464
# 1  5179736.0   판넬 제조및 공사업  판넬 도소매업  창호 철물 공사업  실내외 인테리어 공사업 ...  ...   F   424
# 2  7201804.0   인테리어 및 건축 디자인업  인테리어 및 건축 시공업  인테리어 소품 도소매업  ...  ...   M   732
# 3  5180592.0   형질전환잔디 품종개발생산재배판매  생명공학에 의한 일반작물 식물의 품종개발생산재배...  ...   G   478
# 4  8042873.0   태양광 전력 발전사업  태양광 전력 판매사업  시설물 유지 관리업  전기공사업  ...  ...   D   351
#
# [5 rows x 6 columns]

# %%
# 라벨링
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
encoder.fit(val['small'])
val['small_idx'] = encoder.transform(val['small'])
val.head()
# Out:
#        KEDCD  ... small_idx
# 0  8324863.0  ...       123
# 1  5179736.0  ...       114
# 2  7201804.0  ...       184
# 3  5180592.0  ...       135
# 4  8042873.0  ...       100
#
# [5 rows x 7 columns]

# %%
# 라벨링된 것 매핑

mapping = dict(zip(range(len(encoder.classes_)), encoder.classes_))
mapping
# Out:
# {0: '011',
#  1: '012',
#  2: '013',
#  3: '014',
#  4: '015',
#  5: '020',
#  6: '031',
#  7: '032',
#  8: '051',
#  9: '052',
#  10: '061',
#  11: '062',
#  12: '071',
#  13: '072',
#  14: '080',
#  15: '101',
#  16: '102',
#  17: '103',
#  18: '104',
#  19: '105',
#  20: '106',
#  21: '107',
#  22: '108',
#  23: '111',
#  24: '112',
#  25: '120',
#  26: '131',
#  27: '132',
#  28: '133',
#  29: '134',
#  30: '139',
#  31: '141',
#  32: '142',
#  33: '143',
#  34: '144',
#  35: '151',
#  36: '152',
#  37: '161',
#  38: '162',
#  39: '163',
#  40: '171',
#  41: '172',
#  42: '179',
#  43: '181',
#  44: '182',
#  45: '191',
#  46: '192',
#  47: '201',
#  48: '202',
#  49: '203',
#  50: '204',
#  51: '205',
#  52: '211',
#  53: '212',
#  54: '213',
#  55: '221',
#  56: '222',
#  57: '231',
#  58: '232',
#  59: '233',
#  60: '239',
#  61: '241',
#  62: '242',
#  63: '243',
#  64: '251',
#  65: '252',
#  66: '259',
#  67: '261',
#  68: '262',
#  69: '263',
#  70: '264',
#  71: '265',
# ...

# %%
val= val.loc[:,['BZ_PPOS_ITM_CTT', 'small_idx']]
val.head()
# Out:
#                                      BZ_PPOS_ITM_CTT  small_idx
# 0   생활용품 및 잡화 도소매업  건강식품 건강보조식품 도소매업  유통업  의료용품 기...        123
# 1   판넬 제조및 공사업  판넬 도소매업  창호 철물 공사업  실내외 인테리어 공사업 ...        114
# 2   인테리어 및 건축 디자인업  인테리어 및 건축 시공업  인테리어 소품 도소매업  ...        184
# 3   형질전환잔디 품종개발생산재배판매  생명공학에 의한 일반작물 식물의 품종개발생산재배...        135
# 4   태양광 전력 발전사업  태양광 전력 판매사업  시설물 유지 관리업  전기공사업  ...        100

# %%
val.to_csv('val_small.txt', sep='\t', index=True)

# %% [markdown]
# <font color=yellow> val - se </font>

# %%
val = pd.read_csv('/content/drive/MyDrive/애쓰는 감자/data/val.csv')
val.head()
# Out:
#        KEDCD                                    BZ_PPOS_ITM_CTT  ...  mid Big
# 0  8324863.0   생활용품 및 잡화 도소매업  건강식품 건강보조식품 도소매업  유통업  의료용품 기...  ...  G46   G
# 1  5179736.0   판넬 제조및 공사업  판넬 도소매업  창호 철물 공사업  실내외 인테리어 공사업 ...  ...  F42   F
# 2  7201804.0   인테리어 및 건축 디자인업  인테리어 및 건축 시공업  인테리어 소품 도소매업  ...  ...  M73   M
# 3  5180592.0   형질전환잔디 품종개발생산재배판매  생명공학에 의한 일반작물 식물의 품종개발생산재배...  ...  G47   G
# 4  8042873.0   태양광 전력 발전사업  태양광 전력 판매사업  시설물 유지 관리업  전기공사업  ...  ...  D35   D
#
# [5 rows x 5 columns]

# %%
len(val)
# Out:
# 488386

# %%
for i in range(len(val)):
  if len(val['KSIC10_BZC_CD'][i])<5:
    val=val.drop(index=i)

print(len(val))
# Out:
# 480374

# %%
val['se']=val['KSIC10_BZC_CD'].str[1:5]
val.head()
# Out:
#        KEDCD                                    BZ_PPOS_ITM_CTT  ... Big    se
# 0  8324863.0   생활용품 및 잡화 도소매업  건강식품 건강보조식품 도소매업  유통업  의료용품 기...  ...   G  4649
# 1  5179736.0   판넬 제조및 공사업  판넬 도소매업  창호 철물 공사업  실내외 인테리어 공사업 ...  ...   F  4241
# 2  7201804.0   인테리어 및 건축 디자인업  인테리어 및 건축 시공업  인테리어 소품 도소매업  ...  ...   M  7320
# 3  5180592.0   형질전환잔디 품종개발생산재배판매  생명공학에 의한 일반작물 식물의 품종개발생산재배...  ...   G  4785
# 4  8042873.0   태양광 전력 발전사업  태양광 전력 판매사업  시설물 유지 관리업  전기공사업  ...  ...   D  3511
#
# [5 rows x 6 columns]

# %%
# 라벨링
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
encoder.fit(val['se'])
val['se_idx'] = encoder.transform(val['se'])
val.head()
# Out:
#        KEDCD                                    BZ_PPOS_ITM_CTT  ...    se se_idx
# 0  8324863.0   생활용품 및 잡화 도소매업  건강식품 건강보조식품 도소매업  유통업  의료용품 기...  ...  4649    264
# 1  5179736.0   판넬 제조및 공사업  판넬 도소매업  창호 철물 공사업  실내외 인테리어 공사업 ...  ...  4241    243
# 2  7201804.0   인테리어 및 건축 디자인업  인테리어 및 건축 시공업  인테리어 소품 도소매업  ...  ...  7320    396
# 3  5180592.0   형질전환잔디 품종개발생산재배판매  생명공학에 의한 일반작물 식물의 품종개발생산재배...  ...  4785    304
# 4  8042873.0   태양광 전력 발전사업  태양광 전력 판매사업  시설물 유지 관리업  전기공사업  ...  ...  3511    214
#
# [5 rows x 7 columns]

# %%
# 라벨링된 것 매핑

mapping = dict(zip(range(len(encoder.classes_)), encoder.classes_))
mapping
# Out:
# {0: '0111',
#  1: '0112',
#  2: '0113',
#  3: '0114',
#  4: '0115',
#  5: '0121',
#  6: '0122',
#  7: '0123',
#  8: '0129',
#  9: '0130',
#  10: '0141',
#  11: '0142',
#  12: '0150',
#  13: '0201',
#  14: '0202',
#  15: '0203',
#  16: '0204',
#  17: '0311',
#  18: '0312',
#  19: '0321',
#  20: '0322',
#  21: '0510',
#  22: '0520',
#  23: '0610',
#  24: '0620',
#  25: '0711',
#  26: '0712',
#  27: '0721',
#  28: '0722',
#  29: '0729',
#  30: '0800',
#  31: '1011',
#  32: '1012',
#  33: '1021',
#  34: '1022',
#  35: '1030',
#  36: '1040',
#  37: '1050',
#  38: '1061',
#  39: '1062',
#  40: '1071',
#  41: '1072',
#  42: '1073',
#  43: '1074',
#  44: '1075',
#  45: '1079',
#  46: '1080',
#  47: '1111',
#  48: '1112',
#  49: '1120',
#  50: '1200',
#  51: '1310',
#  52: '1321',
#  53: '1322',
#  54: '1330',
#  55: '1340',
#  56: '1391',
#  57: '1392',
#  58: '1399',
#  59: '1411',
#  60: '1412',
#  61: '1413',
#  62: '1419',
#  63: '1420',
#  64: '1430',
#  65: '1441',
#  66: '1449',
# ...

# %%
val= val.loc[:,['BZ_PPOS_ITM_CTT', 'se_idx']]
val.head()
# Out:
#                                      BZ_PPOS_ITM_CTT  se_idx
# 0   생활용품 및 잡화 도소매업  건강식품 건강보조식품 도소매업  유통업  의료용품 기...     264
# 1   판넬 제조및 공사업  판넬 도소매업  창호 철물 공사업  실내외 인테리어 공사업 ...     243
# 2   인테리어 및 건축 디자인업  인테리어 및 건축 시공업  인테리어 소품 도소매업  ...     396
# 3   형질전환잔디 품종개발생산재배판매  생명공학에 의한 일반작물 식물의 품종개발생산재배...     304
# 4   태양광 전력 발전사업  태양광 전력 판매사업  시설물 유지 관리업  전기공사업  ...     214

# %%
val.to_csv('val_se.txt', sep='\t', index=True)

# %% [markdown]
# <font color=yellow>test data</font>

# %%
test = pd.read_csv('/content/drive/MyDrive/애쓰는 감자/data/test.csv')
test.head()
# Out:
#      KEDCD  ...                                   BZ_PPOS_ITM_CTT2
# 0  1000313  ...   주택건설사업 대지조성업 임대주택사업 토목건축 공사업 도로포장 공사업 전기공사 청부...
# 1  1000929  ...    섬유 제조업 섬유 무역업 섬유 수출입업 부동산 임대업 위 각호에 관련된 부대사업 일체
# 2  1002091  ...   토목공사업 건축공사업 상하수도 공사업 문화재 보수 공사업 부동산 개발업 주택공사업...
# 3    10116  ...   부동산 건설업 부동산 개발업 부동산 금융업 부동산 매매 및 임대업 부동산 이용 개...
# 4   101397  ...  사업  협업적 농업경영을 통하여 생산성을 높이고 조합원의 소득증대를 도모함을 목적으...
#
# [5 rows x 4 columns]

# %%
test = test.loc[:, ['BZ_PPOS_ITM_CTT', 'KSIC10_BZC_CD']]
test.head()
# Out:
#                                      BZ_PPOS_ITM_CTT  KSIC10_BZC_CD
# 0   주택건설사업 대지조성업 임대주택사업 토목건축 공사업 도로포장 공사업 전기공사 청부...            NaN
# 1    섬유 제조업 섬유 무역업 섬유 수출입업 부동산 임대업 위 각호에 관련된 부대사업 일체            NaN
# 2   토목공사업 건축공사업 상하수도 공사업 문화재 보수 공사업 부동산 개발업 주택공사업...            NaN
# 3   부동산 건설업 부동산 개발업 부동산 금융업 부동산 매매 및 임대업 부동산 이용 개...            NaN
# 4  사업  협업적 농업경영을 통하여 생산성을 높이고 조합원의 소득증대를 도모함을 목적으...            NaN

# %%
test.to_csv('test.txt', sep='\t', index=True)

# %% [markdown]
# <font color=skyblue> val.txt <font>

# %%
import pandas as pd
val = pd.read_csv('/content/drive/MyDrive/애쓰는 감자/data/val.csv')
val.head()
# Out:
#        KEDCD                                    BZ_PPOS_ITM_CTT  ...  mid Big
# 0  8324863.0   생활용품 및 잡화 도소매업  건강식품 건강보조식품 도소매업  유통업  의료용품 기...  ...  G46   G
# 1  5179736.0   판넬 제조및 공사업  판넬 도소매업  창호 철물 공사업  실내외 인테리어 공사업 ...  ...  F42   F
# 2  7201804.0   인테리어 및 건축 디자인업  인테리어 및 건축 시공업  인테리어 소품 도소매업  ...  ...  M73   M
# 3  5180592.0   형질전환잔디 품종개발생산재배판매  생명공학에 의한 일반작물 식물의 품종개발생산재배...  ...  G47   G
# 4  8042873.0   태양광 전력 발전사업  태양광 전력 판매사업  시설물 유지 관리업  전기공사업  ...  ...  D35   D
#
# [5 rows x 5 columns]

# %%
val['small']=val['KSIC10_BZC_CD'].str[1:4]
val.head()
# Out:
#                                      BZ_PPOS_ITM_CTT KSIC10_BZC_CD small
# 0   생활용품 및 잡화 도소매업  건강식품 건강보조식품 도소매업  유통업  의료용품 기...        G46499   464
# 1   판넬 제조및 공사업  판넬 도소매업  창호 철물 공사업  실내외 인테리어 공사업 ...        F42412   424
# 2   인테리어 및 건축 디자인업  인테리어 및 건축 시공업  인테리어 소품 도소매업  ...        M73201   732
# 3   형질전환잔디 품종개발생산재배판매  생명공학에 의한 일반작물 식물의 품종개발생산재배...        G47851   478
# 4   태양광 전력 발전사업  태양광 전력 판매사업  시설물 유지 관리업  전기공사업  ...        D35119   351

# %%
val = val.loc[:, ['BZ_PPOS_ITM_CTT', 'small']]
val.head()
# Out:
#                                      BZ_PPOS_ITM_CTT small
# 0   생활용품 및 잡화 도소매업  건강식품 건강보조식품 도소매업  유통업  의료용품 기...   464
# 1   판넬 제조및 공사업  판넬 도소매업  창호 철물 공사업  실내외 인테리어 공사업 ...   424
# 2   인테리어 및 건축 디자인업  인테리어 및 건축 시공업  인테리어 소품 도소매업  ...   732
# 3   형질전환잔디 품종개발생산재배판매  생명공학에 의한 일반작물 식물의 품종개발생산재배...   478
# 4   태양광 전력 발전사업  태양광 전력 판매사업  시설물 유지 관리업  전기공사업  ...   351

# %%
len(val)
# Out:
# 488386

# %%
val.to_csv('/content/drive/MyDrive/애쓰는 감자/data/minz_data/val_small_pred.txt', sep='\t', index=True)
